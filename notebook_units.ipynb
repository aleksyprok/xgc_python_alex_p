# %%
import adios2

# %%
cd /global/homes/q/qt4627/XGC_projects/neoclassical/run_xgca_gpu_batch
# Out:
# /pscratch/sd/q/qt4627/XGC_projects/neoclassical/run_xgca_gpu_batch

# %%
# !bpls -lva xgc.units.bp
# Out:
# File info:
#   of variables:  17
#   of attributes: 0
#   statistics:    Min / Max
#
#   int32_t  diag_1d_period   scalar = 10
#   double   e_ptl_charge_eu  scalar = -1
#   double   e_ptl_mass_au    scalar = 0.0005446
#   double   eq_axis_b        scalar = 2
#   double   eq_axis_r        scalar = 1.23209
#   double   eq_axis_z        scalar = -1.11161e-15
#   double   eq_den_v1        scalar = 3.5e+19
#   double   eq_tempi_v1      scalar = 850
#   double   eq_x_psi         scalar = 0.234282
#   double   eq_x_r           scalar = 1
#   double   eq_x_z           scalar = -9.09091e+09
#   double   i_ptl_charge_eu  scalar = 1
#   double   i_ptl_mass_au    scalar = 2
#   double   sml_dt           scalar = 2.79601e-07
#   int32_t  sml_totalpe      scalar = 8
#   double   sml_tran         scalar = 5.59202e-05
#   int32_t  sml_wedge_n      scalar = 1

# %%
# !bpls -lva xgc.f2d.00010.bp
# Out:
# File info:
#   of variables:  74
#   of attributes: 0
#   statistics:    Min / Max
#
#   double   e_T_para                     {6368} = 702.508 / 995.601
#   double   e_T_perp                     {6368} = 700.904 / 993.323
#   double   e_den                        {6368} = 2.03353e+19 / 4.96845e+19
#   double   e_parallel_flow_df           {6368} = -26301.2 / 7716.21
#   double   e_parallel_flow_f0           {6368} = -2.47414e-10 / 2.32491e-10
#   double   e_poloidal_flow_df           {6368} = -6150.53 / 1264.74
#   double   e_poloidal_flow_f0           {6368} = -944.924 / 2110.94
#   double   e_rad_mom_flux_3db_df        {6368} = 0 / 0
#   double   e_rad_mom_flux_3db_f0        {6368} = 0 / 0
#   double   e_rad_mom_flux_ExB_df        {6368} = -2.95809e-07 / 6.53489e-06
#   double   e_rad_mom_flux_ExB_f0        {6368} = -1.42223e-07 / 1.03831e-08
#   double   e_rad_mom_flux_mag_df        {6368} = -0.000438463 / 0.000404679
# ...

# %%
# !bpls -lva xgc.oneddiag.bp
# Out:
# File info:
#   of variables:  88
#   of attributes: 0
#   statistics:    Min / Max
#
#   double   cden00_1d                     500*{150} = -2.42962e+16 / 1.54351e+16
#   double   e_gc_density_1d               500*{66} = 0 / 5.16991e+19
#   double   e_gc_density_df_1d            500*{66} = 2.03296e+19 / 4.96707e+19
#   double   e_gc_poloidal_flow_1d         500*{66} = -1.43598e+07 / -35908.7
#   double   e_gc_poloidal_flow_df_1d      500*{66} = -4265.33 / 0.0445733
#   double   e_gc_toroidal_flow_1d         500*{66} = -4.0375e+07 / -109597
#   double   e_gc_toroidal_flow_df_1d      500*{66} = -8.12177 / 20686.3
#   double   e_grad_psi_sqr_1d             500*{66} = 4.92151e-05 / 4.98125e-05
#   double   e_grad_psi_sqr_df_1d          500*{66} = -1.16405e-05 / 1.84967e-05
#   double   e_marker_density_1d           500*{66} = 0 / 5.23166e+06
#   double   e_marker_density_df_1d        500*{66} = -11678.4 / 7660.49
# ...
